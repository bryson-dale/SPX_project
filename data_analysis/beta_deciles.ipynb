# %%
# beta_deciles.ipynb

# Import
import sys
import os
import warnings

# Add the 'src' directory (where data_loader.py is located) to the system path
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))
warnings.simplefilter(action='ignore', category=FutureWarning)

# Import DataLoader from the 'src' directory
from data_loader import DataLoader

# Initialize DataLoader with the correct path to the data folder
data_folder_path = os.path.join(os.path.dirname(os.getcwd()), 'data')  # Absolute path to the data folder
data_loader = DataLoader(data_folder=data_folder_path)

# get price and presence_matrix dataframes
prices = data_loader.get_prices()
presence_matrix = data_loader.get_presence_matrix()

# %%
prices
# Out:
# permno                                                     10006  \
# sector     Electronic and Transportation Equipment Manufacturing
# 1925-12-31                                            109.000
# 1926-01-01                                            109.000
# 1926-01-02                                            109.125
# 1926-01-03                                            109.125
# 1926-01-04                                            111.000
# ...                                                       ...
# 2023-12-25                                                NaN
# 2023-12-26                                                NaN
# 2023-12-27                                                NaN
# 2023-12-28                                                NaN
# 2023-12-29                                                NaN
#
# permno                                 10030                        10049  \
# sector     Metal and Machinery Manufacturing Wood and Paper Manufacturing
# ...
